# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"")
df

# %%
d=sns.load_dataset('taxis')
d
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
sns.barplot(x='payment',y='total',data=d,color='red',estimator='mean')
plt.show()
plt.tight_layout()

# %%
sns.histplot(x=d['fare'],color='blue')
plt.show()

# %%
sns.histplot(x=d['fare'],palette=['blue','red'],hue=d['payment'])
plt.show()

# %%
sns.histplot(x=d['fare'],palette=['g','y'],hue=d['payment'])
plt.show()

# %%
sns.distplot(x=d['fare'],hist=True,kde=False)
plt.show()

# %%
sns.distplot(x=d['fare'],kde=True,hist=False)
plt.show()

# %%
sns.boxplot(x=d['fare'],color='blue')
plt.show()

# %%
i=sns.load_dataset('iris')
i
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.boxplot(x=i['petal_length'],color='seagreen')
plt.show()

# %% [markdown]
# #lines are known as lower bond and upper bond
# #line in the box is known is median
# lowe_bound=q1-1.5iqr
# upper_bond=q3+1.5iqr
# iqr=q3-q1

# %%
sns.boxplot(x=i['sepal_width'],color='green')
plt.show()

# %%
sns.boxplot(x=i['sepal_width'],color='brown',y=i['species'])
plt.show()
#in which sector there are outliers

# %%
sns.boxplot(x=i['sepal_width'],palette=['blue','pink','purple'],y=i['species'])
plt.show()
#in which sector there are outliers

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
i_d=sns.load_dataset('iris')
i_d
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(x=i_d['sepal_length'],y=i_d['petal_length'])
plt.show()

# %%
sns.scatterplot(x=i_d['sepal_length'],y=i_d['petal_length'],hue=i_d['species'],palette=['blue','pink','purple'])
plt.show()

# %%
sns.stripplot(x=i_d['species'],y=i_d['sepal_width'],palette=['black','red','green'])
plt.show()

# %%
taxis_data=sns.load_dataset('taxis')

# %%
sns.lineplot(x=taxis_data['tip'],y=taxis_data['fare'])
plt.show()

# %%
sns.lineplot(x=taxis_data['tip'],y=taxis_data['fare'],hue=taxis_data['payment'],palette=['pink','black'])
plt.show()

# %%
sns.lineplot(x=taxis_data['total'],y=taxis_data['fare'],hue=taxis_data['payment'],palette=['green','black'])
plt.show()

# %%
taxis_data[(taxis_data['payment']=='cash') & (taxis_data['tip']>0)]
plt.show()

# %%
sns.lineplot(x=taxis_data['tip'],y=taxis_data['fare'],hue=taxis_data['payment'],palette=['green','black'])
plt.show()

# %%
sns.lineplot(x=taxis_data['total'],y=taxis_data['fare'],hue=taxis_data['payment'],palette=['green','black'])
plt.show()

# %%
taxis_data['payment'].value_counts()
# Out:
# payment
# credit card    4577
# cash           1812
# Name: count, dtype: int64

# %%
t=taxis_data

# %%
sns.countplot(x=t['payment'])
# Out:
# <Axes: xlabel='payment', ylabel='count'>

# %%
sns.countplot(x=t['payment'],hue=t['color'])
plt.show()

# %%
sns.countplot(x=t['payment'],hue=t['color'],palette=['black','pink'])
plt.show()

# %%
data=i_d.drop('species',axis=1)
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
data.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000
