# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=sns.load_dataset('taxis')
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6433 non-null   datetime64[ns]
#  1   dropoff          6433 non-null   datetime64[ns]
#  2   passengers       6433 non-null   int64
#  3   distance         6433 non-null   float64
#  4   fare             6433 non-null   float64
#  5   tip              6433 non-null   float64
#  6   tolls            6433 non-null   float64
#  7   total            6433 non-null   float64
#  8   color            6433 non-null   object
#  9   payment          6389 non-null   object
#  10  pickup_zone      6407 non-null   object
#  11  dropoff_zone     6388 non-null   object
#  12  pickup_borough   6407 non-null   object
#  13  dropoff_borough  6388 non-null   object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(6)
# memory usage: 703.7+ KB

# %%
df.sample(10)#any 10 samples
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 588  2019-03-19 06:28:02 2019-03-19 06:29:04           1      0.17   3.0
# 3279 2019-03-04 22:46:25 2019-03-04 23:07:54           6      6.66  23.5
# 4869 2019-03-01 21:42:07 2019-03-01 21:59:32           1      5.36  18.5
# 6391 2019-03-12 15:53:38 2019-03-12 16:12:33           1      1.68  12.5
# 3268 2019-03-09 15:58:13 2019-03-09 16:21:59           5      1.99  15.0
# 4173 2019-03-31 17:45:14 2019-03-31 17:49:51           1      0.64   5.0
# 461  2019-03-31 10:54:31 2019-03-31 10:57:34           1      0.20   4.0
# 6415 2019-03-03 08:42:49 2019-03-03 08:46:55           1      0.89   5.0
# 1599 2019-03-10 03:17:59 2019-03-10 03:37:49           1      3.62  16.0
# 1843 2019-03-02 04:32:15 2019-03-02 04:41:50           1      2.60  10.0
#
#        tip  tolls  total   color      payment                pickup_zone  \
# 588   0.00    0.0   7.30  yellow         cash        Lincoln Square West
# ...

# %%
df.head(10)# 1st 10 samples
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
# 5 2019-03-11 10:37:23 2019-03-11 10:47:31           1      0.49   7.5  2.16
# 6 2019-03-26 21:07:31 2019-03-26 21:17:29           1      3.65  13.0  2.00
# 7 2019-03-22 12:47:13 2019-03-22 12:58:17           0      1.40   8.5  0.00
# 8 2019-03-23 11:48:50 2019-03-23 12:06:14           1      3.63  15.0  1.00
# 9 2019-03-08 16:18:37 2019-03-08 16:26:57           1      1.52   8.0  1.00
#
#    tolls  total   color      payment                pickup_zone  \
# 0    0.0  12.95  yellow  credit card            Lenox Hill West
# ...

# %%
df.tail(10)#last 10 samples
# Out:
#                   pickup             dropoff  passengers  distance   fare  \
# 6423 2019-03-12 08:10:47 2019-03-12 08:35:35           1      4.30  18.50
# 6424 2019-03-30 20:52:15 2019-03-30 20:59:55           1      1.70   8.00
# 6425 2019-03-07 15:34:30 2019-03-07 16:31:06           1      9.12  26.32
# 6426 2019-03-28 08:04:47 2019-03-28 08:07:46           1      0.71   4.50
# 6427 2019-03-23 18:26:09 2019-03-23 18:49:12           1      7.07  20.00
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.50
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.00
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.00
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.00
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.00
#
#        tip  tolls  total  color      payment          pickup_zone  \
# 6423  0.00    0.0  19.30  green  credit card         Saint Albans
# ...

# %%
df['color'].isnull() #checks whether the position is empty or not
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6428    False
# 6429    False
# 6430    False
# 6431    False
# 6432    False
# Name: color, Length: 6433, dtype: bool

# %%
df['color']
# Out:
# 0       yellow
# 1       yellow
# 2       yellow
# 3       yellow
# 4       yellow
#          ...
# 6428     green
# 6429     green
# 6430     green
# 6431     green
# 6432     green
# Name: color, Length: 6433, dtype: object

# %%
df['color'].isnull().sum()
# Out:
# 0

# %%
df['payment'].isnull().sum()
# Out:
# 44

# %%
df.isnull().sum()
# Out:
# pickup              0
# dropoff             0
# passengers          0
# distance            0
# fare                0
# tip                 0
# tolls               0
# total               0
# color               0
# payment            44
# pickup_zone        26
# dropoff_zone       45
# pickup_borough     26
# dropoff_borough    45
# dtype: int64

# %%
df.isnull().sum()/6433
# Out:
# pickup             0.000000
# dropoff            0.000000
# passengers         0.000000
# distance           0.000000
# fare               0.000000
# tip                0.000000
# tolls              0.000000
# total              0.000000
# color              0.000000
# payment            0.006840
# pickup_zone        0.004042
# dropoff_zone       0.006995
# pickup_borough     0.004042
# dropoff_borough    0.006995
# dtype: float64

# %%
(df.isnull().sum()/6433)*100
# Out:
# pickup             0.000000
# dropoff            0.000000
# passengers         0.000000
# distance           0.000000
# fare               0.000000
# tip                0.000000
# tolls              0.000000
# total              0.000000
# color              0.000000
# payment            0.683973
# pickup_zone        0.404166
# dropoff_zone       0.699518
# pickup_borough     0.404166
# dropoff_borough    0.699518
# dtype: float64

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# pickup             0.000000
# dropoff            0.000000
# passengers         0.000000
# distance           0.000000
# fare               0.000000
# tip                0.000000
# tolls              0.000000
# total              0.000000
# color              0.000000
# payment            0.683973
# pickup_zone        0.404166
# dropoff_zone       0.699518
# pickup_borough     0.404166
# dropoff_borough    0.699518
# dtype: float64

# %% [markdown]
# #Missing data handling
# 1.imputation(fill in the blanks)
#     1.stastical measure
#     2.parameter
# 2.Delete data
#     rows
#     columns

# %%
df.drop('pickup_zone',axis=1)#deletees temporary
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment  \
# ...

# %%
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
df.drop('pickup_zone',axis=1,inplace=True)#deletes permanently and manipulate original df
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment  \
# ...

# %%
df.drop(['payment','pickup'],axis=1)
# Out:
#                  dropoff  passengers  distance  fare   tip  tolls  total  \
# 0    2019-03-23 20:27:24           1      1.60   7.0  2.15    0.0  12.95
# 1    2019-03-04 16:19:00           1      0.79   5.0  0.00    0.0   9.30
# 2    2019-03-27 18:00:25           1      1.37   7.5  2.36    0.0  14.16
# 3    2019-03-10 01:49:51           1      7.70  27.0  6.15    0.0  36.95
# 4    2019-03-30 13:37:14           3      2.16   9.0  1.10    0.0  13.40
# ...                  ...         ...       ...   ...   ...    ...    ...
# 6428 2019-03-31 09:55:27           1      0.75   4.5  1.06    0.0   6.36
# 6429 2019-03-31 18:34:23           1     18.74  58.0  0.00    0.0  58.80
# 6430 2019-03-23 23:14:25           1      4.14  16.0  0.00    0.0  17.30
# 6431 2019-03-04 10:14:29           1      1.12   6.0  0.00    0.0   6.80
# 6432 2019-03-13 19:48:02           1      3.85  15.0  3.36    0.0  20.16
#
#        color                      dropoff_zone pickup_borough dropoff_borough
# ...

# %%
df.drop([2,5,6420],axis=0)
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# 6    2019-03-26 21:07:31 2019-03-26 21:17:29           1      3.65  13.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment  \
# ...

# %%
df.drop([4],axis=0,inplace=True)#deleting rows peramanently
df
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 6    2019-03-26 21:07:31 2019-03-26 21:17:29           1      3.65  13.0
# 7    2019-03-22 12:47:13 2019-03-22 12:58:17           0      1.40   8.5
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment  \
# ...

# %%
df.reset_index()
# Out:
#       index              pickup             dropoff  passengers  distance  \
# 0         0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60
# 1         1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79
# 2         3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70
# 3         6 2019-03-26 21:07:31 2019-03-26 21:17:29           1      3.65
# 4         7 2019-03-22 12:47:13 2019-03-22 12:58:17           0      1.40
# ...     ...                 ...                 ...         ...       ...
# 6424   6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75
# 6425   6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74
# 6426   6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14
# 6427   6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12
# 6428   6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85
#
#       fare   tip  tolls  total   color      payment  \
# ...

# %%
df.reset_index(drop=True)#to set the index after deleting the rows from data frame "MANDATORY"
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 3    2019-03-26 21:07:31 2019-03-26 21:17:29           1      3.65  13.0
# 4    2019-03-22 12:47:13 2019-03-22 12:58:17           0      1.40   8.5
# ...                  ...                 ...         ...       ...   ...
# 6424 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6425 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6426 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6427 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6428 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment  \
# ...

# %%
d=sns.load_dataset('taxis')
d
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
d[d['color']=='yellow']
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 5446 2019-03-11 21:19:42 2019-03-11 21:29:23           1      2.09   9.5
# 5447 2019-03-20 18:09:46 2019-03-20 18:16:52           1      1.52   7.5
# 5448 2019-03-09 11:08:09 2019-03-09 11:18:03           1      2.05   9.5
# 5449 2019-03-22 18:12:50 2019-03-22 18:22:05           1      1.07   7.5
# 5450 2019-03-07 18:02:33 2019-03-07 18:13:32           1      1.80   9.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
d['color']=='yellow'
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 6428    False
# 6429    False
# 6430    False
# 6431    False
# 6432    False
# Name: color, Length: 6433, dtype: bool

# %%
d[d['total']>15]#to access rows based on our condition
# Out:
#                   pickup             dropoff  passengers  distance   fare  \
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.00
# 6    2019-03-26 21:07:31 2019-03-26 21:17:29           1      3.65  13.00
# 8    2019-03-23 11:48:50 2019-03-23 12:06:14           1      3.63  15.00
# 10   2019-03-16 10:02:25 2019-03-16 10:22:29           1      3.90  17.00
# 15   2019-03-16 17:53:34 2019-03-16 18:13:57           3      2.09  13.50
# ...                  ...                 ...         ...       ...    ...
# 6425 2019-03-07 15:34:30 2019-03-07 16:31:06           1      9.12  26.32
# 6427 2019-03-23 18:26:09 2019-03-23 18:49:12           1      7.07  20.00
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.00
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.00
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.00
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
t=d[d['total']>15]
t
# Out:
#                   pickup             dropoff  passengers  distance   fare  \
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.00
# 6    2019-03-26 21:07:31 2019-03-26 21:17:29           1      3.65  13.00
# 8    2019-03-23 11:48:50 2019-03-23 12:06:14           1      3.63  15.00
# 10   2019-03-16 10:02:25 2019-03-16 10:22:29           1      3.90  17.00
# 15   2019-03-16 17:53:34 2019-03-16 18:13:57           3      2.09  13.50
# ...                  ...                 ...         ...       ...    ...
# 6425 2019-03-07 15:34:30 2019-03-07 16:31:06           1      9.12  26.32
# 6427 2019-03-23 18:26:09 2019-03-23 18:49:12           1      7.07  20.00
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.00
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.00
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.00
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
t.head(10)
# Out:
#                 pickup             dropoff  passengers  distance  fare   tip  \
# 3  2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 6  2019-03-26 21:07:31 2019-03-26 21:17:29           1      3.65  13.0  2.00
# 8  2019-03-23 11:48:50 2019-03-23 12:06:14           1      3.63  15.0  1.00
# 10 2019-03-16 10:02:25 2019-03-16 10:22:29           1      3.90  17.0  0.00
# 15 2019-03-16 17:53:34 2019-03-16 18:13:57           3      2.09  13.5  0.00
# 16 2019-03-15 12:36:05 2019-03-15 12:54:28           1      2.12  13.0  0.00
# 17 2019-03-23 20:50:49 2019-03-23 21:02:07           1      2.60  10.5  2.00
# 22 2019-03-28 17:20:54 2019-03-28 17:55:57           1      9.82  31.5  8.31
# 24 2019-03-24 09:53:28 2019-03-24 10:01:22           5      2.89   9.5  3.84
# 25 2019-03-25 08:01:01 2019-03-25 08:13:27           1      1.90  10.0  3.00
#
#     tolls  total   color      payment            pickup_zone  \
# ...

# %%
type(t)
# Out:
# pandas.core.frame.DataFrame

# %%
t[(t['payment']=='cash') and (t['total']>15)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/dz/myr0f5fd0bq11pxqfgksgw940000gn/T/ipykernel_916/3584152149.py in ?()
# ----> 1 t[(t['payment']=='cash') and (t['total']>15)]
#
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
